# %%
#import extension libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas
wb_bty = pandas.read_excel("Information is Beautiful- Data Breaches (public).xlsx")
sheet_1 = pandas.read_excel("Information is Beautiful- Data Breaches (public).xlsx", sheetname= 0)
sheet_2 = pandas.read_excel("Information is Beautiful- Data Breaches (public).xlsx", sheetname= 1)
sheet_3 = pandas.read_excel("Information is Beautiful- Data Breaches (public).xlsx", sheetname= 2)

# %%
sheet_1.loc[sheet_1.YEAR==0,'YEAR']=2004
sheet_1.loc[sheet_1.YEAR==1,'YEAR']=2005
sheet_1.loc[sheet_1.YEAR==2,'YEAR']=2006
sheet_1.loc[sheet_1.YEAR==3,'YEAR']=2007
sheet_1.loc[sheet_1.YEAR==4,'YEAR']=2008
sheet_1.loc[sheet_1.YEAR==5,'YEAR']=2009
sheet_1.loc[sheet_1.YEAR==6,'YEAR']=2010
sheet_1.loc[sheet_1.YEAR==7,'YEAR']=2011
sheet_1.loc[sheet_1.YEAR==8,'YEAR']=2012
sheet_1.loc[sheet_1.YEAR==9,'YEAR']=2013
sheet_1.loc[sheet_1.YEAR==10,'YEAR']=2014
sheet_1.loc[sheet_1.YEAR==11,'YEAR']=2015
sheet_1.loc[sheet_1.YEAR==12,'YEAR']=2016
sheet_1.loc[sheet_1.YEAR==13,'YEAR']=2017
sheet_1.loc[sheet_1.YEAR==14,'YEAR']='Latest'
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Out:
#                                              ENTITY  \
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# 17                         Driving Standards Agency
# ...

# %%
sheet_1
# Out:
#                                              ENTITY  \
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# 17                         Driving Standards Agency
# ...

# %%
sheet_1.columns
# Out:
# Index(['ENTITY', 'ALTERNATIVE NAME', 'STORY', 'YEAR', 'RECORDS LOST',
#        'ORGANISATION', 'METHOD OF LEAK', 'INTERESTING STORY',
#        'NO OF RECORDS STOLEN', 'DATA SENSITIVITY', 'UNUSED', 'UNUSED.1',
#        'EXCLUDE', 'UNNAMED: 13', '1ST SOURCE LINK', '2ND SOURCE LINK',
#        '3RD SOURCE', 'SOURCE NAME'],
#       dtype='object')

# %%
sheet_1.to_excel("wb_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-ad8a0bc73e49> in <module>()
# ----> 1 sheet_1.to_excel("wb_data.xlsx")
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1422         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1423                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1424                         engine=engine)
#    1425
#    1426     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# /usr/local/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     620         need_save = False
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-1dbe91b2b5b8> in <module>()
# ----> 1 from .engine import Engine
#
# ModuleNotFoundError: No module named '__main__.engine'; '__main__' is not a package

# %%
sheet_1.to_csv('Data_bty.csv')

# %%
sheet_1.to_excel('Data_bty.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-41c9900c3caa> in <module>()
# ----> 1 sheet_1.to_excel('Data_bty.xlsx')
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1422         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1423                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1424                         engine=engine)
#    1425
#    1426     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# /usr/local/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     620         need_save = False
# ...
